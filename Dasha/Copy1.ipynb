# %% [markdown]
# # Our database with companies that left Russia in 2022

# %%
import pandas as pd

# %%
df_actions_tone = pd.read_csv("new database with Actions.csv")
df_int = pd.read_excel("new database with INT.xlsx")
spark = pd.read_csv("spark.csv", delimiter=";")

# %%
df_actions_tone = df_actions_tone.drop('Unnamed: 0', axis = 1)
df_actions_tone = df_actions_tone.rename(columns = {'tone': 'Tone'})
df_actions_tone = df_actions_tone.sort_values(by='Company')
df_actions_tone = df_actions_tone.reset_index(drop=True)
df_actions_tone.head(1)
# Out:
#           Company                                             Action  \
# 0  1840 & Company  ['suspend', 'aesthetics', 'operations', ',', '...
#
#       Industry        Country  Tone
# 0  Health Care  United States     2

# %%
df_int = df_int.rename(columns={'i': 'Company'})
df_int = df_int.rename(columns={'ИНН': 'INT'})
df_int = df_int.sort_values(by='Company')
df_int = df_int.reset_index(drop=True)
df_int.head(1)
# Out:
#           Company                                             Action  \
# 0  1840 & Company  suspend aesthetics operations, pause new clini...
#
#       Industry        Country         INT
# 0  Health Care  United States  7743855873

# %%
df1 = df_actions_tone.copy()
df2 = df_int.copy()

# Merge the two datasets based on the "Company" column
data = pd.merge(df1, df2, on='Company')
data.head(1)
# Out:
#           Company                                           Action_x  \
# 0  1840 & Company  ['suspend', 'aesthetics', 'operations', ',', '...
#
#     Industry_x      Country_x  Tone  \
# 0  Health Care  United States     2
#
#                                             Action_y   Industry_y  \
# 0  suspend aesthetics operations, pause new clini...  Health Care
#
#        Country_y         INT
# 0  United States  7743855873

# %%
# Select the desired columns
desired_columns = ['Company', 'Action_x', 'Industry_x', 'Country_x', 'Tone', 'INT']
data = data[desired_columns]
data.head(1)
# Out:
#           Company                                           Action_x  \
# 0  1840 & Company  ['suspend', 'aesthetics', 'operations', ',', '...
#
#     Industry_x      Country_x  Tone         INT
# 0  Health Care  United States     2  7743855873

# %%
# Rename the columns
data.columns = ['Company', 'Action', 'Industry', 'Country', 'Tone', 'INT']

# %%
data
# Out:
#                                        Company  \
# 0                               1840 & Company
# 1                                    1Password
# 2                                        1xBet
# 3                           3HC Semiconductors
# 4                                           3M
# ...                                        ...
# 3339  Французский автомобильный концерн Re..."
# 3340                           Хостинг Ukraine
# 3341                                    Шальке
# 3342                                   Эвертон
# 3343                                   ЯБпоела
#
#                                                  Action  \
# 0     ['suspend', 'aesthetics', 'operations', ',', '...
# 1         ['suspend', 'new', 'investments/development']
# 2     ['ending', 'new', 'investments', 'where', 'has...
# 3     ['some', 'clients', 'no', 'longer', 'supplied'...
# 4     ['suspend', 'supply', 'of', 'parts', 'and', 'd...
# ...                                                 ...
# 3339                       ['no', 'new', 'investments']
# 3340  ['ban', 'people', 'with', 'ties', 'to', 'russi...
# 3341                          ['no', 'new', 'business']
# 3342  ['stopped', 'renewing', 'and', 'underwriting',...
# 3343  ['no', 'new', 'investments', 'and', 'expansion...
#
#                     Industry        Country  Tone         INT
# 0                Health Care  United States     2  7743855873
# 1     Consumer Discretionary         France     2  7704662187
# 2                 Financials    Netherlands     0         NaN
# 3                  Materials         France     0  3528103017
# 4                Industrials    Netherlands     1  9704116463
# ...                      ...            ...   ...         ...
# 3339               Utilities         France     0  5003026630
# 3340                     NGO        Germany     0  7453231464
# 3341             Industrials        Denmark     0         NaN
# 3342              Financials  United States     0  6829067343
# 3343             Industrials  United States     0         NaN
#
# [3344 rows x 6 columns]

# %% [markdown]
# # Spark database

# %%
spark.head()
# Out:
#    №     Наименование  Регистрационный номер Наименование на английском  \
# 0  1    3М ВОЛГА, ООО           1.121674e+12              3M VOLGA, OOO
# 1  2         CCC, ООО           1.198617e+12                OOO C, CJSC
# 2  3      WIX-SZ, ООО           1.133538e+12                WIX-SZ, OOO
# 3  4  А.С. ГРУПП, ООО           1.192375e+12            A.S. GROUP, LLC
# 4  5         АББ, ООО           1.027739e+12                   ABB, OOO
#
#   Краткое наименование Дата регистрации Возраст компании, лет  \
# 0        ООО"3М ВОЛГА"       16.08.2012                  10,5
# 1            ООО "CCC"       18.06.2019                   3,5
# 2         ООО "WIX-SZ"       12.02.2013                  10,0
# 3     ООО "А.С. ГРУПП"       16.04.2019                   4,0
# 4            ООО "АББ"       13.12.2000                  22,0
#
#    Код налогоплательщика                           Вид деятельности/отрасль  \
# 0             1646033450         Торговля оптовая прочими бытовыми товарами
# 1             8608060872  Строительство инженерных коммуникаций для водо...
# 2             3526030067  Работы строительные специализированные прочие,...
# 3             2310213891  Консультирование по вопросам коммерческой деят...
# 4             7727180430  Торговля оптовая производственным электротехни...
#
#               Организационно-правовая форма  ... 2017, Выручка, RUB  \
# 0  Общества с ограниченной ответственностью  ...         13 300 000
# 1  Общества с ограниченной ответственностью  ...                NaN
# 2  Общества с ограниченной ответственностью  ...         18 049 000
# 3  Общества с ограниченной ответственностью  ...                NaN
# 4  Общества с ограниченной ответственностью  ...     21 012 268 000
#
#   2018, Выручка, RUB 2019, Выручка, RUB 2020, Выручка, RUB 2021, Выручка, RUB  \
# 0        104 722 000        218 916 000         19 484 000        153 458 000
# 1                NaN                NaN         65 126 000         47 022 000
# 2         11 592 000          5 157 000         11 399 000         15 481 000
# 3                NaN          1 586 000          5 833 000                NaN
# 4     23 143 045 000     22 362 311 000     23 544 957 000     23 339 744 000
#
#   2017, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -154 449 000
# 1                                             NaN
# 2                                         558 000
# 3                                             NaN
# 4                                   1 908 551 000
#
#   2018, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -147 371 000
# 1                                             NaN
# 2                                         548 000
# 3                                             NaN
# 4                                   1 011 902 000
#
#   2019, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -135 529 000
# 1                                        -381 000
# 2                                         279 000
# 3                                      -2 667 000
# 4                                   1 142 817 000
#
#   2020, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -196 685 000
# 1                                       8 130 000
# 2                                         422 000
# 3                                        -914 000
# 4                                     -33 797 000
#
#   2021, Прибыль (убыток) до налогообложения , RUB
# 0                                    -172 832 000
# 1                                         213 000
# 2                                         543 000
# 3                                             NaN
# 4                                   1 555 765 000
#
# [5 rows x 28 columns]

# %% [markdown]
# <span style="font-size: 17px;"> Delete all unnecessary columns

# %%
columns_to_drop = ['№', 'Наименование', 'Краткое наименование', 'Регистрационный номер', 'Дата регистрации']
spark = spark.drop(columns_to_drop, axis=1)

# %%
print(spark.columns)
# Out:
# Index(['Наименование на английском', 'Возраст компании, лет',
#        'Код налогоплательщика', 'Вид деятельности/отрасль',
#        'Организационно-правовая форма', 'Форма собственности',
#        'Размер компании', '2017, Среднесписочная численность работников',
#        '2018, Среднесписочная численность работников',
#        '2019, Среднесписочная численность работников',
#        '2020, Среднесписочная численность работников',
#        '2021, Среднесписочная численность работников', 'Мои списки',
#        '2017, Выручка, RUB', '2018, Выручка, RUB', '2019, Выручка, RUB',
#        '2020, Выручка, RUB', '2021, Выручка, RUB',
#        '2017, Прибыль (убыток) до налогообложения , RUB',
#        '2018, Прибыль (убыток) до налогообложения , RUB',
#        '2019, Прибыль (убыток) до налогообложения , RUB',
#        '2020, Прибыль (убыток) до налогообложения , RUB',
#        '2021, Прибыль (убыток) до налогообложения , RUB'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 17px;"> Rename columns 'Наименование на английском' and 'Код налогоплательщика' to 'Company' and 'INT'

# %%
spark = spark.rename(columns={"Наименование на английском": "Company"})
spark = spark.rename(columns={"Код налогоплательщика": "INT"})
# spark['Company'] = spark['Company'].str.lower()

# %%
spark.head(1)
# Out:
#          Company Возраст компании, лет         INT  \
# 0  3M VOLGA, OOO                  10,5  1646033450
#
#                      Вид деятельности/отрасль  \
# 0  Торговля оптовая прочими бытовыми товарами
#
#               Организационно-правовая форма  \
# 0  Общества с ограниченной ответственностью
#
#                          Форма собственности    Размер компании  \
# 0  Собственность иностранных юридических лиц  Малые предприятия
#
#   2017, Среднесписочная численность работников  \
# 0                                            4
#
#   2018, Среднесписочная численность работников  \
# 0                                            8
#
#   2019, Среднесписочная численность работников  ... 2017, Выручка, RUB  \
# 0                                            7  ...         13 300 000
#
#   2018, Выручка, RUB 2019, Выручка, RUB 2020, Выручка, RUB 2021, Выручка, RUB  \
# 0        104 722 000        218 916 000         19 484 000        153 458 000
#
#   2017, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -154 449 000
#
#   2018, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -147 371 000
#
#   2019, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -135 529 000
#
#   2020, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -196 685 000
#
#   2021, Прибыль (убыток) до налогообложения , RUB
# 0                                    -172 832 000
#
# [1 rows x 23 columns]

# %% [markdown]
# # Merging two databases into one

# %%
df_merged = data.merge(spark, on='INT')

# %%
df_merged.head(30)
# Out:
#                    Company_x  \
# 0             1840 & Company
# 1         3HC Semiconductors
# 2                         3M
# 3                        AAK
# 4                        ABC
# 5                   ABC News
# 6                       ACCA
# 7                      ADAMA
# 8                        ADM
# 9                        ADP
# 10                     AECOM
# 11               AERECO S.A.
# 12              AERIN Beauty
# 13                AF Holding
# 14                      AFRY
# 15                   AG Barr
# 16               AGB Nielsen
# 17                       AGC
# 18          AGC Glass Europe
# 19                AGGREKO UK
# 20                     AICPA
# 21     AIG Insurance Company
# 22  AL-KO Vehicle Technology
# 23            ALD Automotive
# 24                       AMD
# 25        ALKALOID AD SKOPJE
# 26                   AM Best
# 27                     AMCOR
# 28                      ANAS
# 29           AOOK Technology
#
#                                                Action                Industry  \
# 0   ['suspend', 'aesthetics', 'operations', ',', '...             Health Care
# 1   ['some', 'clients', 'no', 'longer', 'supplied'...               Materials
# 2   ['suspend', 'supply', 'of', 'parts', 'and', 'd...             Industrials
# 3                  ['suspended', 'some', 'shipments']  Information Technology
# 4           ['no', 'new', 'business', 'in', 'russia']  Consumer Discretionary
# 5   ['suspend', 'new', 'investments', 'in', 'russia']             Industrials
# 6    ['suspend', 'new', 'investment', 'in', 'russia']             Industrials
# 7   ['no', 'further', 'investments/clinical', 'tri...             Health Care
# 8   ['pause', 'all', 'new', 'capital', 'investment...             Health Care
# 9   ['no', 'new', 'russian', 'investments', ';', '...                  Energy
# 10  ['still', 'operating', 'in', 'russia', ';', 'n...             Industrials
# 11  ['halting', 'advertising', 'and', 'promotional...             Health Care
# 12                   ['new', 'projects', 'cancelled']             Industrials
# 13  ['stopped', 'new', 'investment', 'and', 'techn...                  Energy
# 14         ['suspend', 'investments', 'in', 'russia']               Materials
# 15  ['suspended', 'business', 'development', 'and'...             Industrials
# 16                            ['stop', 'cooperation']             Industrials
# 17  ['suspend', 'only', 'exports', 'to', 'russia',...  Consumer Discretionary
# 18  ['cancel', 'investments', 'in', 'a', 'brand', ...               Materials
# 19  ['suspend', 'new', 'contracts', ';', 'cotinue'...             Industrials
# 20  ['maintain', 'russian', 'natural', 'gas', 'pro...                  Energy
# 21  ['decision', 'to', 'renew', 'production', 'in'...  Consumer Discretionary
# 22  ['suspend', 'almost', 'all', 'sales', 'in', 'r...  Information Technology
# 23  ['stop', 'shipments', 'to', 'russia', ';', 'ma...             Industrials
# 24  ['reduced', 'deliveries', 'and', 'supplies', '...               Materials
# 25  ['suspended', 'sales', 'of', 'global', 'brands...        Consumer Staples
# 26  ['halt', 'new', 'business', '&', 'scale', 'bac...             Industrials
# 27  ['stop', 'processing', 'payments', 'to', 'and'...              Financials
# 28  ['stopped', 'new', 'business', 'and', 'investm...               Materials
# 29  ['suspend', 'operations', 'in', 'russia', 'and...             Industrials
#
#            Country  Tone         INT                              Company_y  \
# 0    United States     2  7743855873                             EBBVI, OOO
# 1           France     0  3528103017                                ALS, AO
# 2      Netherlands     1  9704116463                            AIRBUS, LLC
# 3            Japan     0  7714391842                    FUDZHIFILM RUS, OOO
# 4          Austria     0  9715417769                    HERZ GROUP RUS, LLC
# 5    United States     2  7728053385                       UPDK-KHAINS, OOO
# 6           France     2  7725704127                  ID LOGISTIKS RUS, OOO
# 7    United States     0  7701620453                MERCK LIFE SCIENCE, LLC
# 8      Switzerland     0  7705772224                    NOVARTIS FARMA, OOO
# 9          Austria     0  7728139307                               OMV, OOO
# 10         Germany     0  1327013715                  REMONDIS SARANSK, OOO
# 11          France     1  7705018169                     SANOFI ROSSIYA, AO
# 12         Belgium     0  7703698470                     SARENS RUSSIA, LLC
# 13   United States     0  7709542704               SHLYUMBERZHE VOSTOK, OOO
# 14         Germany     2  5246032499                          SHOTT FP, OOO
# 15     Switzerland     0  1007019482                                    SGS
# 16  Czech Republic     0  7838394684          GRUPPA KOMPANI SIGMA-GAZ, ZAO
# 17     Netherlands     2  7703388189                 SIGNIFAI EVRAZIYA, OOO
# 18         Belgium     0  7722279315                            SOUDAL, LLC
# 19     Netherlands     2  7704588720                        TMF RUS, A, LLC
# 20         Germany     0  8904047896                           ACHIMGAZ, AO
# 21           Japan     0  4802011710                  IOKOKHAMA R.P.Z., OOO
# 22   United States     2  7705298420                       KORNING SNG, OOO
# 23   United States     0  5103070023                             APATIT, AO
# 24          Norway     0  5103070023                             APATIT, AO
# 25   United States     0  7705598512               SIRIAL PARTNERS RUS, OOO
# 26         Germany     0  7725600174                          MALE RUS, OOO
# 27         Finland     0  7715294714  PROMYSHLENNAYA KOMPANIYA VESTKON, OOO
# 28         Germany     0  4028044157                              TKSI, OOO
# 29  United Kingdom     2  6449103789                ASSA GRUPP, OOO UK CHPP
#
#    Возраст компании, лет                           Вид деятельности/отрасль  \
# 0                   10,5       Торговля оптовая фармацевтической продукцией
# 1                   17,5                    Производство промышленных газов
# 2                    1,0                Деятельность туристических агентств
# 3                   29,0              Торговля оптовая неспециализированная
# 4                    0,5  Торговля оптовая водопроводным и отопительным ...
# 5                   31,0  Управление недвижимым имуществом за вознагражд...
# 6                   12,5           Деятельность по складированию и хранению
# 7                   17,5  Деятельность предпринимательских членских неко...
# 8                   16,0       Торговля оптовая фармацевтической продукцией
# 9                   26,5  Деятельность по финансовой аренде (лизингу/суб...
# 10                  11,5                                       Сбор отходов
# 11                  28,0       Торговля оптовая фармацевтической продукцией
# 12                  14,0  Деятельность вспомогательная прочая, связанная...
# 13                  18,5  Предоставление услуг в области добычи нефти и ...
# 14                  15,0            Производство стекла и изделий из стекла
# 15                  12,0      Деятельность стоянок для транспортных средств
# 16                  15,0  Деятельность по управлению финансово-промышлен...
# 17                   7,5    Торговля оптовая электрической бытовой техникой
# 18                  20,0          Торговля оптовая промышленными химикатами
# 19                  17,0  Деятельность административно-хозяйственная ком...
# 20                  17,0  Предоставление прочих услуг в области добычи н...
# 21                  14,0  Производство резиновых шин, покрышек и камер; ...
# 22                  23,5    Торговля оптовая изделиями из керамики и стекла
# 23                  30,5        Производство удобрений и азотных соединений
# 24                  30,5        Производство удобрений и азотных соединений
# 25                  18,5  Производство хлеба и мучных кондитерских издел...
# 26                  16,0  Производство оборудования специального назначе...
# 27                  21,5        Деятельность по управлению ценными бумагами
# 28                  14,0                        Ремонт машин и оборудования
# 29                   0,5  Управление эксплуатацией нежилого фонда за воз...
#
#                   Организационно-правовая форма  ... 2017, Выручка, RUB  \
# 0      Общества с ограниченной ответственностью  ...     10 254 588 000
# 1              Непубличные акционерные общества  ...      4 241 597 000
# 2      Общества с ограниченной ответственностью  ...                NaN
# 3      Общества с ограниченной ответственностью  ...      3 178 782 000
# 4      Общества с ограниченной ответственностью  ...                NaN
# 5      Общества с ограниченной ответственностью  ...                NaN
# 6      Общества с ограниченной ответственностью  ...      1 230 715 000
# 7      Общества с ограниченной ответственностью  ...        502 171 000
# 8      Общества с ограниченной ответственностью  ...     18 184 446 000
# 9      Общества с ограниченной ответственностью  ...          4 295 000
# 10     Общества с ограниченной ответственностью  ...        243 879 000
# 11             Непубличные акционерные общества  ...     48 552 088 000
# 12     Общества с ограниченной ответственностью  ...          2 714 000
# 13     Общества с ограниченной ответственностью  ...     17 298 415 000
# 14     Общества с ограниченной ответственностью  ...        872 483 000
# 15  Гаражные и гаражно-строительные кооперативы  ...                NaN
# 16             Непубличные акционерные общества  ...        148 746 000
# 17     Общества с ограниченной ответственностью  ...      4 199 382 000
# 18     Общества с ограниченной ответственностью  ...      2 292 694 000
# 19     Общества с ограниченной ответственностью  ...        152 484 000
# 20             Непубличные акционерные общества  ...     31 026 771 000
# 21     Общества с ограниченной ответственностью  ...      3 730 319 000
# 22     Общества с ограниченной ответственностью  ...      1 777 899 000
# 23             Непубличные акционерные общества  ...    104 322 901 000
# 24             Непубличные акционерные общества  ...    104 322 901 000
# 25     Общества с ограниченной ответственностью  ...      5 145 033 000
# 26     Общества с ограниченной ответственностью  ...      2 317 390 000
# 27     Общества с ограниченной ответственностью  ...                NaN
# 28     Общества с ограниченной ответственностью  ...        168 364 000
# 29     Общества с ограниченной ответственностью  ...                NaN
#
#    2018, Выручка, RUB 2019, Выручка, RUB 2020, Выручка, RUB  \
# 0       9 951 071 000     10 208 217 000     11 038 418 000
# 1       4 085 493 000      4 219 756 000      4 261 008 000
# 2                 NaN                NaN                NaN
# 3       3 672 729 000      2 898 280 000      2 800 149 000
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6       1 627 697 000      2 572 849 000      2 239 789 000
# 7         780 527 000        831 842 000      1 349 847 000
# 8      21 894 506 000     28 138 077 000     31 854 990 000
# 9           3 292 000          5 660 000          7 350 000
# 10        620 617 000        737 376 000        817 289 000
# 11     52 828 353 000     53 640 035 000     57 690 865 000
# 12         11 128 000        608 047 000         24 686 000
# 13     18 580 426 000     19 444 690 000     18 437 542 000
# 14        931 277 000      1 158 236 000      1 454 217 000
# 15                NaN                NaN                NaN
# 16        578 276 000                NaN                NaN
# 17      5 007 178 000      5 583 653 000      6 659 324 000
# 18      2 667 315 000      3 129 058 000      2 955 832 000
# 19        176 881 000        161 415 000        125 695 000
# 20     41 216 830 000     68 881 977 000     84 998 805 000
# 21      4 109 279 000      4 226 608 000      4 250 307 000
# 22      2 024 114 000      1 351 149 000      1 252 019 000
# 23    203 281 465 000    216 108 010 000    214 124 018 000
# 24    203 281 465 000    216 108 010 000    214 124 018 000
# 25      3 967 241 000      4 340 079 000      6 470 356 000
# 26      2 852 508 000      2 608 499 000      2 963 629 000
# 27                NaN                NaN                NaN
# 28        180 698 000        398 121 000        198 295 000
# 29                NaN                NaN                NaN
#
#    2021, Выручка, RUB 2017, Прибыль (убыток) до налогообложения , RUB  \
# 0      10 107 069 000                                      39 767 000
# 1       3 935 799 000                                   1 758 438 000
# 2                 NaN                                             NaN
# 3       3 410 160 000                                     117 504 000
# 4                 NaN                                             NaN
# 5                 NaN                                         -27 000
# 6       2 639 568 000                                      80 349 000
# 7       1 831 439 000                                     102 374 000
# 8      39 722 228 000                                     -46 362 000
# 9           7 103 000                                         -58 000
# 10        857 278 000                                      39 271 000
# 11     51 063 363 000                                   2 855 163 000
# 12        199 254 000                                      -4 235 000
# 13     16 872 928 000                                     387 851 000
# 14      1 653 433 000                                      34 901 000
# 15                NaN                                             NaN
# 16                NaN                                       6 378 000
# 17      6 422 601 000                                      79 300 000
# 18      3 718 110 000                                       6 768 000
# 19        130 984 000                                      97 408 000
# 20    104 767 675 000                                  22 569 965 000
# 21      4 655 860 000                                     232 905 000
# 22      1 288 365 000                                     184 836 000
# 23                NaN                                  26 339 899 000
# 24                NaN                                  26 339 899 000
# 25      7 407 405 000                                   1 080 083 000
# 26      4 269 053 000                                      55 337 000
# 27                NaN                                   5 573 253 000
# 28        300 136 000                                      16 306 000
# 29                NaN                                             NaN
#
#    2018, Прибыль (убыток) до налогообложения , RUB  \
# 0                                      115 612 000
# 1                                    1 923 752 000
# 2                                              NaN
# 3                                       49 294 000
# 4                                              NaN
# 5                                         -657 000
# 6                                      -79 454 000
# 7                                       91 240 000
# 8                                      991 082 000
# 9                                       -3 088 000
# 10                                      92 899 000
# 11                                   1 240 666 000
# 12                                        -677 000
# 13                                      21 085 000
# 14                                      46 039 000
# 15                                             NaN
# 16                                      26 536 000
# 17                                     354 902 000
# 18                                      87 621 000
# 19                                     138 728 000
# 20                                  33 599 574 000
# 21                                     136 739 000
# 22                                     -34 487 000
# 23                                  39 316 843 000
# 24                                  39 316 843 000
# 25                                    -275 936 000
# 26                                     150 754 000
# 27                                   6 877 200 000
# 28                                      15 378 000
# 29                                             NaN
#
#    2019, Прибыль (убыток) до налогообложения , RUB  \
# 0                                      -98 477 000
# 1                                    2 082 180 000
# 2                                              NaN
# 3                                      188 041 000
# 4                                              NaN
# 5                                         -473 000
# 6                                     -168 129 000
# 7                                       54 501 000
# 8                                      161 520 000
# 9                                          845 000
# 10                                     110 683 000
# 11                                     692 304 000
# 12                                       8 318 000
# 13                                     802 112 000
# 14                                     127 833 000
# 15                                             NaN
# 16                                             NaN
# 17                                     182 471 000
# 18                                      95 660 000
# 19                                      77 155 000
# 20                                  35 289 230 000
# 21                                     177 410 000
# 22                                      75 122 000
# 23                                  49 036 357 000
# 24                                  49 036 357 000
# 25                                     172 871 000
# 26                                      10 557 000
# 27                                   2 430 322 000
# 28                                      19 030 000
# 29                                             NaN
#
#    2020, Прибыль (убыток) до налогообложения , RUB  \
# 0                                      436 625 000
# 1                                    2 148 197 000
# 2                                              NaN
# 3                                      265 433 000
# 4                                              NaN
# 5                                         -115 000
# 6                                       65 183 000
# 7                                      306 309 000
# 8                                       88 970 000
# 9                                        2 063 000
# 10                                      64 890 000
# 11                                   1 020 790 000
# 12                                     -30 516 000
# 13                                     554 894 000
# 14                                     240 416 000
# 15                                             NaN
# 16                                             NaN
# 17                                     139 153 000
# 18                                     111 836 000
# 19                                      65 813 000
# 20                                  26 555 009 000
# 21                                     358 204 000
# 22                                       8 248 000
# 23                                  34 547 804 000
# 24                                  34 547 804 000
# 25                                     820 247 000
# 26                                      46 603 000
# 27                                   4 325 567 000
# 28                                      18 664 000
# 29                                             NaN
#
#    2021, Прибыль (убыток) до налогообложения , RUB
# 0                                      492 786 000
# 1                                    2 038 560 000
# 2                                              NaN
# 3                                      446 284 000
# 4                                              NaN
# 5                                          -83 000
# 6                                      140 244 000
# 7                                      346 203 000
# 8                                      559 463 000
# 9                                        1 690 000
# 10                                      18 843 000
# 11                                   2 168 412 000
# 12                                      18 775 000
# 13                                    -148 325 000
# 14                                     337 360 000
# 15                                             NaN
# 16                                             NaN
# 17                                      54 893 000
# 18                                      90 515 000
# 19                                      14 699 000
# 20                                  75 623 456 000
# 21                                     126 015 000
# 22                                    -182 927 000
# 23                                             NaN
# 24                                             NaN
# 25                                   1 368 735 000
# 26                                     204 799 000
# 27                                   9 464 242 000
# 28                                      34 601 000
# 29                                             NaN
#
# [30 rows x 28 columns]

# %%
df_merged = df_merged.rename(columns={"Company_y": "Company"})

df_merged = df_merged.drop({'Company_x', 'INT', 
                          '2017, Среднесписочная численность работников', 
                          '2018, Среднесписочная численность работников', 
                          '2019, Среднесписочная численность работников',
                          '2020, Среднесписочная численность работников', 
                          '2021, Среднесписочная численность работников',
                          'Мои списки'}, axis=1)

# %%
df_merged = df_merged[['Company', 'Industry', 'Country', 'Action', 'Tone', 'Возраст компании, лет',
       'Вид деятельности/отрасль', 'Организационно-правовая форма',
       'Форма собственности', 'Размер компании', '2017, Выручка, RUB',
       '2018, Выручка, RUB', '2019, Выручка, RUB', '2020, Выручка, RUB',
       '2021, Выручка, RUB', '2017, Прибыль (убыток) до налогообложения , RUB',
       '2018, Прибыль (убыток) до налогообложения , RUB',
       '2019, Прибыль (убыток) до налогообложения , RUB',
       '2020, Прибыль (убыток) до налогообложения , RUB',
       '2021, Прибыль (убыток) до налогообложения , RUB']]

# %%
df_merged.head()
# Out:
#                Company                Industry        Country  \
# 0           EBBVI, OOO             Health Care  United States
# 1              ALS, AO               Materials         France
# 2          AIRBUS, LLC             Industrials    Netherlands
# 3  FUDZHIFILM RUS, OOO  Information Technology          Japan
# 4  HERZ GROUP RUS, LLC  Consumer Discretionary        Austria
#
#                                               Action  Tone  \
# 0  ['suspend', 'aesthetics', 'operations', ',', '...     2
# 1  ['some', 'clients', 'no', 'longer', 'supplied'...     0
# 2  ['suspend', 'supply', 'of', 'parts', 'and', 'd...     1
# 3                 ['suspended', 'some', 'shipments']     0
# 4          ['no', 'new', 'business', 'in', 'russia']     0
#
#   Возраст компании, лет                           Вид деятельности/отрасль  \
# 0                  10,5       Торговля оптовая фармацевтической продукцией
# 1                  17,5                    Производство промышленных газов
# 2                   1,0                Деятельность туристических агентств
# 3                  29,0              Торговля оптовая неспециализированная
# 4                   0,5  Торговля оптовая водопроводным и отопительным ...
#
#               Организационно-правовая форма  \
# 0  Общества с ограниченной ответственностью
# 1          Непубличные акционерные общества
# 2  Общества с ограниченной ответственностью
# 3  Общества с ограниченной ответственностью
# 4  Общества с ограниченной ответственностью
#
#                               Форма собственности      Размер компании  \
# 0       Собственность иностранных юридических лиц  Крупные предприятия
# 1  Совместная частная и иностранная собственность  Крупные предприятия
# 2                           Частная собственность                  NaN
# 3       Собственность иностранных юридических лиц  Крупные предприятия
# 4                           Частная собственность                  NaN
#
#   2017, Выручка, RUB 2018, Выручка, RUB 2019, Выручка, RUB 2020, Выручка, RUB  \
# 0     10 254 588 000      9 951 071 000     10 208 217 000     11 038 418 000
# 1      4 241 597 000      4 085 493 000      4 219 756 000      4 261 008 000
# 2                NaN                NaN                NaN                NaN
# 3      3 178 782 000      3 672 729 000      2 898 280 000      2 800 149 000
# 4                NaN                NaN                NaN                NaN
#
#   2021, Выручка, RUB 2017, Прибыль (убыток) до налогообложения , RUB  \
# 0     10 107 069 000                                      39 767 000
# 1      3 935 799 000                                   1 758 438 000
# 2                NaN                                             NaN
# 3      3 410 160 000                                     117 504 000
# 4                NaN                                             NaN
#
#   2018, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     115 612 000
# 1                                   1 923 752 000
# 2                                             NaN
# 3                                      49 294 000
# 4                                             NaN
#
#   2019, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     -98 477 000
# 1                                   2 082 180 000
# 2                                             NaN
# 3                                     188 041 000
# 4                                             NaN
#
#   2020, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     436 625 000
# 1                                   2 148 197 000
# 2                                             NaN
# 3                                     265 433 000
# 4                                             NaN
#
#   2021, Прибыль (убыток) до налогообложения , RUB
# 0                                     492 786 000
# 1                                   2 038 560 000
# 2                                             NaN
# 3                                     446 284 000
# 4                                             NaN

# %%
database = df_merged.copy()

# %% [markdown]
# <span style="font-size: 17px;"> The column 'Возраст компании, лет' is of string datatype. To make it float datatype, we replace , with .

# %%
if database['Возраст компании, лет'].dtype == object:
        # Replace commas with periods in the column
        database['Возраст компании, лет'] = database['Возраст компании, лет'].str.replace(',', '.')
database['Возраст компании, лет'] = database['Возраст компании, лет'].astype(float)

# %% [markdown]
# <span style="font-size: 17px;"> Some columns has big number with spaces, therefore they are of a string type.  To make them float datatype, we delete all unnecassary spaces

# %%
database['2017, Выручка, RUB'] = database['2017, Выручка, RUB'].str.replace(' ', '').astype(float)
database['2018, Выручка, RUB'] = database['2018, Выручка, RUB'].str.replace(' ', '').astype(float)
database['2019, Выручка, RUB'] = database['2019, Выручка, RUB'].str.replace(' ', '').astype(float)
database['2020, Выручка, RUB'] = database['2020, Выручка, RUB'].str.replace(' ', '').astype(float)
database['2021, Выручка, RUB'] = database['2021, Выручка, RUB'].str.replace(' ', '').astype(float)
database['2017, Прибыль (убыток) до налогообложения , RUB'] = database['2017, Прибыль (убыток) до налогообложения , RUB'].str.replace(' ', '').astype(float)
database['2018, Прибыль (убыток) до налогообложения , RUB'] = database['2018, Прибыль (убыток) до налогообложения , RUB'].str.replace(' ', '').astype(float)
database['2019, Прибыль (убыток) до налогообложения , RUB'] = database['2019, Прибыль (убыток) до налогообложения , RUB'].str.replace(' ', '').astype(float)
database['2020, Прибыль (убыток) до налогообложения , RUB'] = database['2020, Прибыль (убыток) до налогообложения , RUB'].str.replace(' ', '').astype(float)
database['2021, Прибыль (убыток) до налогообложения , RUB'] = database['2021, Прибыль (убыток) до налогообложения , RUB'].str.replace(' ', '').astype(float)

# %%
database.head(5)
# Out:
#                Company                Industry        Country  \
# 0           EBBVI, OOO             Health Care  United States
# 1              ALS, AO               Materials         France
# 2          AIRBUS, LLC             Industrials    Netherlands
# 3  FUDZHIFILM RUS, OOO  Information Technology          Japan
# 4  HERZ GROUP RUS, LLC  Consumer Discretionary        Austria
#
#                                               Action  Tone  \
# 0  ['suspend', 'aesthetics', 'operations', ',', '...     2
# 1  ['some', 'clients', 'no', 'longer', 'supplied'...     0
# 2  ['suspend', 'supply', 'of', 'parts', 'and', 'd...     1
# 3                 ['suspended', 'some', 'shipments']     0
# 4          ['no', 'new', 'business', 'in', 'russia']     0
#
#    Возраст компании, лет                           Вид деятельности/отрасль  \
# 0                   10.5       Торговля оптовая фармацевтической продукцией
# 1                   17.5                    Производство промышленных газов
# 2                    1.0                Деятельность туристических агентств
# 3                   29.0              Торговля оптовая неспециализированная
# 4                    0.5  Торговля оптовая водопроводным и отопительным ...
#
#               Организационно-правовая форма  \
# 0  Общества с ограниченной ответственностью
# 1          Непубличные акционерные общества
# 2  Общества с ограниченной ответственностью
# 3  Общества с ограниченной ответственностью
# 4  Общества с ограниченной ответственностью
#
#                               Форма собственности      Размер компании  \
# 0       Собственность иностранных юридических лиц  Крупные предприятия
# 1  Совместная частная и иностранная собственность  Крупные предприятия
# 2                           Частная собственность                  NaN
# 3       Собственность иностранных юридических лиц  Крупные предприятия
# 4                           Частная собственность                  NaN
#
#    2017, Выручка, RUB  2018, Выручка, RUB  2019, Выручка, RUB  \
# 0        1.025459e+10        9.951071e+09        1.020822e+10
# 1        4.241597e+09        4.085493e+09        4.219756e+09
# 2                 NaN                 NaN                 NaN
# 3        3.178782e+09        3.672729e+09        2.898280e+09
# 4                 NaN                 NaN                 NaN
#
#    2020, Выручка, RUB  2021, Выручка, RUB  \
# 0        1.103842e+10        1.010707e+10
# 1        4.261008e+09        3.935799e+09
# 2                 NaN                 NaN
# 3        2.800149e+09        3.410160e+09
# 4                 NaN                 NaN
#
#    2017, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     3.976700e+07
# 1                                     1.758438e+09
# 2                                              NaN
# 3                                     1.175040e+08
# 4                                              NaN
#
#    2018, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     1.156120e+08
# 1                                     1.923752e+09
# 2                                              NaN
# 3                                     4.929400e+07
# 4                                              NaN
#
#    2019, Прибыль (убыток) до налогообложения , RUB  \
# 0                                    -9.847700e+07
# 1                                     2.082180e+09
# 2                                              NaN
# 3                                     1.880410e+08
# 4                                              NaN
#
#    2020, Прибыль (убыток) до налогообложения , RUB  \
# 0                                     4.366250e+08
# 1                                     2.148197e+09
# 2                                              NaN
# 3                                     2.654330e+08
# 4                                              NaN
#
#    2021, Прибыль (убыток) до налогообложения , RUB
# 0                                     4.927860e+08
# 1                                     2.038560e+09
# 2                                              NaN
# 3                                     4.462840e+08
# 4                                              NaN

# %% [markdown]
# # Handling missing values

# %% [markdown]
# <span style="font-size: 17px;"> Count total NaN at each column in a database

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", database.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  Company                                              0
# Industry                                             0
# Country                                              0
# Action                                               0
# Tone                                                 0
# Возраст компании, лет                                0
# Вид деятельности/отрасль                             0
# Организационно-правовая форма                        0
# Форма собственности                                  0
# Размер компании                                     77
# 2017, Выручка, RUB                                 123
# 2018, Выручка, RUB                                 111
# 2019, Выручка, RUB                                 104
# 2020, Выручка, RUB                                 100
# 2021, Выручка, RUB                                 106
# 2017, Прибыль (убыток) до налогообложения , RUB    110
# 2018, Прибыль (убыток) до налогообложения , RUB    103
# 2019, Прибыль (убыток) до налогообложения , RUB     89
# 2020, Прибыль (убыток) до налогообложения , RUB     86
# 2021, Прибыль (убыток) до налогообложения , RUB     92
# dtype: int64

# %% [markdown]
# <span style="font-size: 17px;"> Visualize missing values in dataset

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (0.5.2)
# Requirement already satisfied: scipy in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.7.1)
# Requirement already satisfied: numpy in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from missingno) (1.20.3)
# Requirement already satisfied: matplotlib in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from missingno) (3.4.3)
# Requirement already satisfied: seaborn in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from missingno) (0.11.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: six in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pandas>=0.23 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from seaborn->missingno) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <span style="font-size: 17px;"> Visualize the number of missing values as a bar chart

# %%
import missingno as msno
msno.bar(database)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style="font-size: 17px;"> Visualize the correlation between the number of missing values in different columns as a heatmap.
#
# <span style="font-size: 17px;"> As we see below, there is a diagonal with values 0.9, which means that profit and insome highly correlates in terms of null values (if profit value is present, then income value is likely to be present too)

# %%
msno.heatmap(database)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style="font-size: 17px;"> Delete all rows where more than 6 NaN values exist

# %%
database.dropna(thresh=database.shape[1] - 6, inplace=True)

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", database.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  Company                                             0
# Industry                                            0
# Country                                             0
# Action                                              0
# Tone                                                0
# Возраст компании, лет                               0
# Вид деятельности/отрасль                            0
# Организационно-правовая форма                       0
# Форма собственности                                 0
# Размер компании                                    10
# 2017, Выручка, RUB                                 38
# 2018, Выручка, RUB                                 26
# 2019, Выручка, RUB                                 18
# 2020, Выручка, RUB                                 14
# 2021, Выручка, RUB                                 34
# 2017, Прибыль (убыток) до налогообложения , RUB    30
# 2018, Прибыль (убыток) до налогообложения , RUB    20
# 2019, Прибыль (убыток) до налогообложения , RUB     5
# 2020, Прибыль (убыток) до налогообложения , RUB     6
# 2021, Прибыль (убыток) до налогообложения , RUB    25
# dtype: int64

# %%
database.shape
# Out:
# (389, 20)

# %% [markdown]
# <span style="font-size: 17px;"> Delete all rows where Nan values exist

# %%
columns=['2017, Выручка, RUB', '2018, Выручка, RUB', '2019, Выручка, RUB', '2020, Выручка, RUB', '2021, Выручка, RUB']
dfs = [database.dropna(subset=[col]) for col in columns]

# Drop rows with NaN values for each profit column separately
intersection_indices = set(dfs[0].index).intersection(*[df.index for df in dfs[1:]])

# Select rows with indices present in the intersection
df_filtered = database.loc[intersection_indices]
df_filtered.reset_index(drop=True, inplace=True)
print(" \nCount total NaN at each column in a DataFrame : \n\n", df_filtered.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  Company                                            0
# Industry                                           0
# Country                                            0
# Action                                             0
# Tone                                               0
# Возраст компании, лет                              0
# Вид деятельности/отрасль                           0
# Организационно-правовая форма                      0
# Форма собственности                                0
# Размер компании                                    0
# 2017, Выручка, RUB                                 0
# 2018, Выручка, RUB                                 0
# 2019, Выручка, RUB                                 0
# 2020, Выручка, RUB                                 0
# 2021, Выручка, RUB                                 0
# 2017, Прибыль (убыток) до налогообложения , RUB    1
# 2018, Прибыль (убыток) до налогообложения , RUB    2
# 2019, Прибыль (убыток) до налогообложения , RUB    0
# 2020, Прибыль (убыток) до налогообложения , RUB    2
# 2021, Прибыль (убыток) до налогообложения , RUB    2
# dtype: int64

# %%
# New dataset without NaN values in columns:
# Возраст компании, лет                               
# Вид деятельности/отрасль                            
# Организационно-правовая форма                       
# Форма собственности                                 
# Размер компании                                     
# 2017, Выручка, RUB                                  
# 2018, Выручка, RUB                                  
# 2019, Выручка, RUB                                  
# 2020, Выручка, RUB                                  
# 2021, Выручка, RUB

df_filtered.shape
# Out:
# (318, 20)

# %% [markdown]
# # Clusterisation (k-prototypes)

# %% [markdown]
# <span style="font-size: 17px;"> Delete columns that has NaN values in it

# %%
database2 = database.drop({'Company', 'Industry', 'Country', '2017, Выручка, RUB',
       '2018, Выручка, RUB', '2019, Выручка, RUB', '2020, Выручка, RUB',
       '2021, Выручка, RUB', '2017, Прибыль (убыток) до налогообложения , RUB',
       '2018, Прибыль (убыток) до налогообложения , RUB',
       '2019, Прибыль (убыток) до налогообложения , RUB',
       '2020, Прибыль (убыток) до налогообложения , RUB',
       '2021, Прибыль (убыток) до налогообложения , RUB', 'Размер компании'}, axis = 1)

# %%
database2.head(1)
# Out:
#                                               Action  Tone  \
# 0  ['suspend', 'aesthetics', 'operations', ',', '...     2
#
#    Возраст компании, лет                      Вид деятельности/отрасль  \
# 0                   10.5  Торговля оптовая фармацевтической продукцией
#
#               Организационно-правовая форма  \
# 0  Общества с ограниченной ответственностью
#
#                          Форма собственности
# 0  Собственность иностранных юридических лиц

# %%
pip install kmodes
# Out:
# Requirement already satisfied: kmodes in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.20.3)
# Requirement already satisfied: scipy>=0.13.3 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dl3/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from kmodes.kprototypes import KPrototypes

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", database2.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  Action                           0
# Tone                             0
# Возраст компании, лет            0
# Вид деятельности/отрасль         0
# Организационно-правовая форма    0
# Форма собственности              0
# dtype: int64

# %%
mark_array=database2.values

# %% [markdown]
# <span style="font-size: 17px;"> Mark columns that has float datatypes

# %%
mark_array[:, 0] = mark_array[:, 0].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pk/czrcbd3n6tx7f3m676x_gw700000gn/T/ipykernel_78803/3834149843.py in <module>
# ----> 1 mark_array[:, 0] = mark_array[:, 0].astype(float)
#
# ValueError: could not convert string to float: "['suspend', 'aesthetics', 'operations', ',', 'pause', 'new', 'clinical', 'trials']"

# %%
mark_array

# %%
kproto = KPrototypes(n_clusters=5, verbose=2,max_iter=30)
clusters = kproto.fit_predict(mark_array, categorical=[1, 2, 3])

# %%
print(kproto.cluster_centroids_)

# %%
cluster_dict=[]
for c in clusters:
    cluster_dict.append(c)

# %%
cluster_dict

# %%
database2['cluster']=cluster_dict

# %%
database2

# %%
database2[database2['cluster']== 0].head(10)

# %%
database2[database2['cluster']== 1].head(10)

# %%
database2[database2['cluster']== 2].head(10)

# %% [markdown]
# <span style="font-size: 17px;"> Visualisation:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

database2.columns = ["Возраст компании, лет", "Вид деятельности/отрасль", "Организационно-правовая форма", "Форма собственности", "cluster"]
sns.pairplot(database2, hue="cluster")

# %%
sns.boxplot(x="cluster", y="Возраст компании, лет", data=database2)

# %%
sns.boxplot(x="cluster", y="Организационно-правовая форма", data=database2)

# %%
sns.boxplot(x="cluster", y="Форма собственности", data=database2)

# %%
database2.columns = ["Вид деятельности/отрасль", "Возраст компании, лет", "Организационно-правовая форма", "Форма собственности", "cluster"]
sns.pairplot(database2, hue="cluster")

# %% [markdown]
# ### Clusterisation of dataset with profit

# %%
df_filtered = df_filtered.drop({'Company', 'Industry', 'Country', '2017, Прибыль (убыток) до налогообложения , RUB',
       '2018, Прибыль (убыток) до налогообложения , RUB',
       '2019, Прибыль (убыток) до налогообложения , RUB',
       '2020, Прибыль (убыток) до налогообложения , RUB',
       '2021, Прибыль (убыток) до налогообложения , RUB'}, axis = 1)

# %%
df_filtered.head(1)

# %%
pip install kmodes

# %% [markdown]
# <span style="font-size: 17px;"> Check that there are no NaN values in the dataset</span>

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", df_filtered.isnull().sum())

# %%
mark_array=df_filtered.values

# %% [markdown]
# <span style="font-size: 17px;"> Mark columns that has float datatypes

# %%
mark_array[:, 0] = mark_array[:, 0].astype(float)
mark_array[:, 5] = mark_array[:, 5].astype(float)
mark_array[:, 6] = mark_array[:, 6].astype(float)
mark_array[:, 7] = mark_array[:, 7].astype(float)
mark_array[:, 8] = mark_array[:, 8].astype(float)
mark_array[:, 9] = mark_array[:, 9].astype(float)

# %%
mark_array

# %%
kproto = KPrototypes(n_clusters=3, verbose=2,max_iter=30)
clusters = kproto.fit_predict(mark_array, categorical=[1, 2, 3, 4])

# %%
print(kproto.cluster_centroids_)

# %%
cluster_dict=[]
for c in clusters:
    cluster_dict.append(c)

# %%
cluster_dict

# %%
df_filtered['cluster']=cluster_dict

# %%
df_filtered

# %%
df_filtered[df_filtered['cluster']== 0].head(10)

# %%
df_filtered[df_filtered['cluster']== 1].head(10)

# %%
df_filtered[df_filtered['cluster']== 2].head(10)

# %%
df_filtered[df_filtered['cluster']== 0].count()

# %% [markdown]
# # Graphs

# %%
import matplotlib.pyplot as plt

# %%
database3 = database.copy()
database3

# %% [markdown]
# ### Countries

# %% [markdown]
# <span style="font-size: 17px;"> Value_counts() returns the count of unique values in the 'Country' column, and head(10) selects the first 10 values, which represent the top 10 countries with the highest counts.</span>

# %%
df_countries = database3['Country'].value_counts().head(10)

# %%
df_countries = df_countries.to_frame().reset_index()

# %%
df_countries

# %%
# Increase the figure size and adjust the spacing
plt.figure(figsize=(12, 8))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Plot the bar chart
df_countries.plot(kind='bar', x='index', y='Country', color='pink')

# Set the labels and title
plt.xlabel('Country', fontsize=12, labelpad=10)
plt.ylabel('Number of Companies', fontsize=12, labelpad=10)
plt.title('Number of Companies per Country', fontsize=14, fontweight='bold', pad=20)

# Adjust the font size and rotation of the x-axis labels
plt.xticks(fontsize=10, rotation=45, ha='right')

# Adjust the font size of the y-axis labels
plt.yticks(fontsize=10)

# Remove the top and right spines (borders)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ### Industries:

# %%
df_industries = database3['Industry'].value_counts()
df_industries = df_industries.to_frame().reset_index()

# %%
import matplotlib.pyplot as plt

# Increase the figure size and adjust the spacing
plt.figure(figsize=(16, 8))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Plot the bar chart
df_industries.plot(kind='bar', x='index', y='Industry', color='#a7e8a9')

# Set the labels and title
plt.xlabel('Industry', fontsize=12, labelpad=10)
plt.ylabel('Number of Companies', fontsize=12, labelpad=10)
plt.title('Number of Companies per Industry', fontsize=14, fontweight='bold', pad=20)

# Adjust the font size and rotation of the x-axis labels
plt.xticks(fontsize=10, rotation=45, ha='right')

# Adjust the font size of the y-axis labels
plt.yticks(fontsize=10)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# ### Size

# %%
df_size = database3['Размер компании'].value_counts()
df_size = df_size.to_frame().reset_index()

# %%
import matplotlib.pyplot as plt

# Increase the figure size and adjust the spacing
plt.figure(figsize=(14, 8))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Plot the bar chart
df_size.plot(kind='bar', x='index', y='Размер компании', color='#b6dffc')

# Set the labels and title
plt.xlabel('Size', fontsize=12, labelpad=10)
plt.ylabel('Number of Companies', fontsize=12, labelpad=10)
plt.title('Number of Companies per Size', fontsize=14, fontweight='bold', pad=20)

# Adjust the font size and rotation of the x-axis labels
plt.xticks(fontsize=10, rotation=45, ha='right')

# Adjust the font size of the y-axis labels
plt.yticks(fontsize=10)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.show()

# %%
database3.head()

# %% [markdown]
# ### Age

# %%
database3['Возраст компании, лет'].plot(kind='hist', bins=30)

plt.xlabel('Age of Company')
plt.ylabel('Count')
plt.title('Distribution of Company Age')

plt.show()

# %% [markdown]
# ### Organisational form

# %%
df_form = database3['Организационно-правовая форма'].value_counts().head(5)
df_form = df_form.to_frame().reset_index()
df_form

# %%
# Increase the figure size and adjust the spacing
plt.figure(figsize=(10, 5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Plot the bar chart
df_form.plot(kind='bar', x='index', y='Организационно-правовая форма', color='#ccccff')

# Set the labels and title
plt.xlabel('Type of form', fontsize=12, labelpad=10)
plt.ylabel('Number of Companies', fontsize=12, labelpad=10)
plt.title('Number of Companies per Organisational form', fontsize=14, fontweight='bold', pad=20)

# Adjust the font size and rotation of the x-axis labels
plt.xticks(fontsize=10, rotation=45, ha='right')

# Adjust the font size of the y-axis labels
plt.yticks(fontsize=10)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.show()

# %% [markdown]
# ### Form of property

# %%
df_form2 = database3['Форма собственности'].value_counts().head(5)
df_form2 = df_form2.to_frame().reset_index()
df_form2

# %%
# Increase the figure size and adjust the spacing
plt.figure(figsize=(10, 5))
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

# Plot the bar chart
df_form2.plot(kind='bar', x='index', y='Форма собственности', color='#ffcc99')

# Set the labels and title
plt.xlabel('Type of form', fontsize=12, labelpad=10)
plt.ylabel('Number of Companies', fontsize=12, labelpad=10)
plt.title('Number of Companies per Form of property', fontsize=14, fontweight='bold', pad=20)

# Adjust the font size and rotation of the x-axis labels
plt.xticks(fontsize=10, rotation=45, ha='right')

# Adjust the font size of the y-axis labels
plt.yticks(fontsize=10)

# Remove the top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add grid lines to the plot
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Show the plot
plt.show()
